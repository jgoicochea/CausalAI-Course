# %% [markdown]
# ### 1 Loading the data

# %%
setwd("D:/PUCP/JP-TC")

# Load the data
data <- read.csv('wage2015_subsample_inference.csv')

# Separate the features and the target variable
X <- data[, !(names(data) %in% c('wage', 'lwage'))]  # Drop columns 'wage' and 'lwage'
y <- data['lwage']

# %%
# Load necessary package
library(stats)

# Create the design matrix
X_flexible <- model.matrix(~ 0 + sex + (exp1 + exp2 + exp3 + exp4 + hsg + scl + clg + ad + so + we + ne + 
                                         factor(occ2) + factor(ind2))^2, data = X)

# %%
y <- as.matrix(y)

X_flexible <- as.matrix(X_flexible)

# %% [markdown]
# ### 2 Creating the Lasso Cross-Validation Procedure

# %% [markdown]
# 4. The `log_grid` function is pretty straight forward

# %%
log_grid <- function(lower, upper, log_step) {
  log_grid <- seq(lower, upper, length.out = 1 / log_step)
  return(exp(log_grid))
}

# %% [markdown]
# 5. To code the `k_folds` function, there are many different approaches. However, we sticked to using only numpy. With this library, we exploited the kronecker product operation and block matrices to build the $k$-folds. Also, we addressed the issue of divisibility between the sample size $n$ and $k$ using an if-else statement depending on the module of $n/k$

# %%
k_folds <- function(data, k = 5) {
  
  module <- nrow(data) %% k
  floor <- nrow(data) %/% k 
  
  if (module == 0) {
    trues <- matrix(1, nrow = floor, ncol = 1)
    split_matrix <- kronecker(diag(k), trues)
  } else {
    trues_g1 <- matrix(1, nrow = floor + 1, ncol = 1)
    split_matrix_g1 <- kronecker(diag(module), trues_g1)
    
    trues_g2 <- matrix(1, nrow = floor, ncol = 1)
    split_matrix_g2 <- kronecker(diag(k - module), trues_g2)
    
    split_matrix <- rbind(
      cbind(split_matrix_g1, matrix(0, nrow = nrow(split_matrix_g1), ncol = ncol(split_matrix_g2))),
      cbind(matrix(0, nrow = nrow(split_matrix_g2), ncol = ncol(split_matrix_g1)), split_matrix_g2)
    )
  }
  
  sm_bool <- split_matrix == 1
  splits <- lapply(1:k, function(x) sm_bool[, x])
  
  return(splits)
}

# %% [markdown]
# 6. For the `optimal_lambda` search function, we basically adapted the code provided in the labs so it can use the functions of log-grid and our own $k$-folds function

# %%
optimal_lambda <- function(Y, X, lambda_bounds, k = 5, niter = 100) {
  
  library(glmnet)
  
  Y <- drop(Y)
  
  if (is.vector(X)) {
    X <- matrix(X, ncol = 1)
  }
  
  folds <- k_folds(X, k)
  all_lambdas <- exp(seq(lambda_bounds[1], lambda_bounds[2], length.out = niter))
  all_mse <- numeric(niter)
  
  for (l in all_lambdas) {
    split_pes <- numeric(k)
    
    for (i in seq_len(k)) {
      X_train <- X[!folds[[i]], ]
      X_test <- X[folds[[i]], ]
      y_train <- Y[!folds[[i]]]
      y_test <- Y[folds[[i]]]
      
      model <- glmnet(X_train, y_train, alpha = 1, lambda = l,standardize = FALSE)
      predict <- predict(model, X_test, s = l)
      
      pe <- sum((y_test - predict)^2)
      split_pes[i] <- pe
    }
    
    all_mse[which(all_lambdas == l)] <- mean(split_pes)
  }
  
  selected <- which.min(all_mse)
  optimal_lambda <- all_lambdas[selected]
  optimal_model <- glmnet(X, Y, alpha = 1, lambda = optimal_lambda)
  optimal_coef <- coef(optimal_model, s = optimal_lambda)
  
  output <- list(
    optimal_lambda = optimal_lambda,
    optimal_coef = optimal_coef,
    all_lambdas = all_lambdas,
    all_mse = all_mse
  )
  
  return(output)
}

# %% [markdown]
# 7. The `predict_model` function can be easily implemented using the results of `optimal_function`

# %%
predict_model <- function(optimal_model, X) {
  
  intercept <- matrix(1, nrow = nrow(X), ncol = 1)
  Z <- cbind(intercept, X)
  
  return(Z %*% optimal_model$optimal_coef)
}

# %% [markdown]
# ### 3 Applying the Lasso Cross-Validation Procedure

# %% [markdown]
# We split the sample in train and test

# %%
library(caTools)


split <- sample.split(y, SplitRatio = 0.75)
X_flexible_train <- subset(X_flexible, split == TRUE)
X_flexible_test <- subset(X_flexible, split == FALSE)
y_train <- y[split]
y_test <- y[!split]

# %% [markdown]
# 8. We perform the OLS fitting

# %%
model_ls <- lm(y_train ~ ., data = data.frame(y_train = y_train, X_flexible_train))

# %% [markdown]
# 9. Npw we search the optimal lambda using our `optimal_lambda` function

# %%
model_lasso <- optimal_lambda(y_train, X_flexible_train, c(-7, 7))

# %%
print(model_lasso$optimal_lambda)
# Out:
# [1] 0.001209955

# %%
print(model_lasso$optimal_coef)
# Out:
# 981 x 1 sparse Matrix of class "dgCMatrix"
#                                          s1
# (Intercept)                    2.703255e+00
# sex                           -5.268292e-02
# exp1                           8.876025e-03
# exp2                           .
# exp3                           .
# exp4                           .
# hsg                            .
# scl                            .
# clg                            3.566800e-01
# ad                             4.109067e-01
# so                             .
# we                             .
# ne                            -4.891785e-03
# factor(occ2)1                  2.112583e-01
# factor(occ2)2                  1.833252e-01
# factor(occ2)3                  1.185715e-01
# factor(occ2)4                  1.286261e-01
# factor(occ2)5                  .
# factor(occ2)6                 -6.791555e-02
# factor(occ2)7                  .
# factor(occ2)8                 -8.839535e-02
# factor(occ2)9                  .
# factor(occ2)10                 7.069746e-02
# factor(occ2)11                -2.503734e-02
# factor(occ2)12                 .
# factor(occ2)13                 .
# factor(occ2)14                -4.411823e-02
# factor(occ2)15                -4.451471e-02
# factor(occ2)16                 1.738897e-02
# factor(occ2)17                -1.363240e-01
# factor(occ2)18                 .
# factor(occ2)19                 .
# factor(occ2)20                 .
# factor(occ2)21                 .
# factor(occ2)22                -1.479977e-01
# factor(ind2)3                 -2.299914e-02
# factor(ind2)4                  .
# factor(ind2)5                  .
# factor(ind2)6                  .
# factor(ind2)7                 -8.785499e-02
# factor(ind2)8                  .
# factor(ind2)9                  .
# factor(ind2)10                -1.823153e-02
# factor(ind2)11                 4.222510e-02
# factor(ind2)12                 1.848132e-01
# factor(ind2)13                 .
# factor(ind2)14                 .
# factor(ind2)15                 .
# factor(ind2)16                -6.603958e-03
# factor(ind2)17                -3.979091e-02
# factor(ind2)18                -1.588826e-01
# factor(ind2)19                -5.420581e-02
# factor(ind2)20                -1.887671e-01
# factor(ind2)21                 .
# factor(ind2)22                 6.874269e-02
# exp1:exp2                      .
# exp1:exp3                      .
# exp1:exp4                      .
# exp1:hsg                       .
# exp1:scl                       2.652825e-03
# exp1:clg                       3.810381e-04
# exp1:ad                        6.552293e-03
# exp1:so                        2.548329e-03
# exp1:we                        7.219640e-03
# exp1:ne                        1.545416e-03
# exp1:factor(occ2)2             .
# exp1:factor(occ2)3            -4.027979e-03
# exp1:factor(occ2)4             .
# exp1:factor(occ2)5             1.106483e-02
# exp1:factor(occ2)6             .
# exp1:factor(occ2)7             1.774978e-03
# exp1:factor(occ2)8             5.633151e-04
# exp1:factor(occ2)9             1.073849e-02
# exp1:factor(occ2)10            1.002377e-02
# exp1:factor(occ2)11           -2.760978e-03
# exp1:factor(occ2)12            6.347298e-03
# exp1:factor(occ2)13           -8.857462e-03
# exp1:factor(occ2)14           -9.449525e-03
# exp1:factor(occ2)15           -5.438263e-03
# exp1:factor(occ2)16            8.161710e-03
# exp1:factor(occ2)17            .
# exp1:factor(occ2)18            .
# exp1:factor(occ2)19            .
# exp1:factor(occ2)20           -7.037527e-04
# exp1:factor(occ2)21            .
# exp1:factor(occ2)22            .
# exp1:factor(ind2)3             .
# exp1:factor(ind2)4            -5.533378e-04
# exp1:factor(ind2)5             .
# exp1:factor(ind2)6             .
# exp1:factor(ind2)7             .
# exp1:factor(ind2)8            -7.605524e-03
# exp1:factor(ind2)9             9.744256e-04
# exp1:factor(ind2)10            .
# exp1:factor(ind2)11            .
# exp1:factor(ind2)12            .
# exp1:factor(ind2)13            .
# exp1:factor(ind2)14            1.429891e-03
# exp1:factor(ind2)15            8.354971e-03
# exp1:factor(ind2)16           -2.010443e-04
# exp1:factor(ind2)17            .
# exp1:factor(ind2)18            .
# exp1:factor(ind2)19            .
# exp1:factor(ind2)20            .
# exp1:factor(ind2)21           -5.139632e-03
# exp1:factor(ind2)22            4.611821e-03
# exp2:exp3                      .
# exp2:exp4                      .
# exp2:hsg                       .
# exp2:scl                       .
# exp2:clg                       .
# exp2:ad                        .
# exp2:so                        .
# exp2:we                        .
# exp2:ne                        .
# exp2:factor(occ2)2             .
# exp2:factor(occ2)3             .
# exp2:factor(occ2)4            -2.946857e-02
# exp2:factor(occ2)5             .
# exp2:factor(occ2)6             .
# exp2:factor(occ2)7             .
# exp2:factor(occ2)8             1.158445e-03
# exp2:factor(occ2)9             .
# exp2:factor(occ2)10            .
# exp2:factor(occ2)11            .
# exp2:factor(occ2)12            .
# exp2:factor(occ2)13           -3.000066e-03
# exp2:factor(occ2)14            .
# exp2:factor(occ2)15            .
# exp2:factor(occ2)16            .
# exp2:factor(occ2)17            .
# exp2:factor(occ2)18            .
# exp2:factor(occ2)19            1.089095e-02
# exp2:factor(occ2)20            .
# exp2:factor(occ2)21            .
# exp2:factor(occ2)22           -4.281197e-03
# exp2:factor(ind2)3             .
# exp2:factor(ind2)4             .
# exp2:factor(ind2)5             .
# exp2:factor(ind2)6             .
# exp2:factor(ind2)7             .
# exp2:factor(ind2)8             .
# exp2:factor(ind2)9             .
# exp2:factor(ind2)10            .
# exp2:factor(ind2)11            .
# exp2:factor(ind2)12            .
# exp2:factor(ind2)13           -6.661701e-03
# exp2:factor(ind2)14            .
# exp2:factor(ind2)15            .
# exp2:factor(ind2)16            .
# exp2:factor(ind2)17            .
# exp2:factor(ind2)18            .
# exp2:factor(ind2)19            2.017575e-02
# exp2:factor(ind2)20           -1.098313e-03
# exp2:factor(ind2)21            .
# exp2:factor(ind2)22            .
# exp3:exp4                      .
# exp3:hsg                       .
# exp3:scl                       .
# exp3:clg                       .
# exp3:ad                       -4.603529e-03
# exp3:so                        .
# exp3:we                        .
# exp3:ne                        .
# exp3:factor(occ2)2             .
# exp3:factor(occ2)3             .
# exp3:factor(occ2)4             .
# exp3:factor(occ2)5             .
# exp3:factor(occ2)6             .
# exp3:factor(occ2)7            -3.470762e-03
# exp3:factor(occ2)8             .
# exp3:factor(occ2)9            -5.098104e-03
# exp3:factor(occ2)10            .
# exp3:factor(occ2)11            .
# exp3:factor(occ2)12            .
# exp3:factor(occ2)13            .
# exp3:factor(occ2)14            .
# exp3:factor(occ2)15            .
# exp3:factor(occ2)16            .
# exp3:factor(occ2)17            .
# exp3:factor(occ2)18            .
# exp3:factor(occ2)19            .
# exp3:factor(occ2)20            .
# exp3:factor(occ2)21            .
# exp3:factor(occ2)22            .
# exp3:factor(ind2)3             .
# exp3:factor(ind2)4             .
# exp3:factor(ind2)5             7.085756e-04
# exp3:factor(ind2)6             .
# exp3:factor(ind2)7             .
# exp3:factor(ind2)8             .
# exp3:factor(ind2)9             .
# exp3:factor(ind2)10            .
# exp3:factor(ind2)11            .
# exp3:factor(ind2)12           -2.228727e-03
# exp3:factor(ind2)13            .
# exp3:factor(ind2)14            .
# exp3:factor(ind2)15            .
# exp3:factor(ind2)16            .
# exp3:factor(ind2)17            .
# exp3:factor(ind2)18            .
# exp3:factor(ind2)19            .
# exp3:factor(ind2)20           -4.781948e-03
# exp3:factor(ind2)21            .
# exp3:factor(ind2)22            .
# exp4:hsg                       3.747216e-04
# exp4:scl                      -1.354162e-04
# exp4:clg                       .
# exp4:ad                        .
# exp4:so                        .
# exp4:we                       -8.793821e-04
# exp4:ne                        5.053796e-04
# exp4:factor(occ2)2            -1.869559e-03
# exp4:factor(occ2)3             1.387740e-03
# exp4:factor(occ2)4             8.774860e-04
# exp4:factor(occ2)5             .
# exp4:factor(occ2)6            -6.933621e-04
# exp4:factor(occ2)7             .
# exp4:factor(occ2)8             .
# exp4:factor(occ2)9             .
# exp4:factor(occ2)10           -2.009458e-03
# exp4:factor(occ2)11            .
# exp4:factor(occ2)12            .
# exp4:factor(occ2)13            .
# exp4:factor(occ2)14            .
# exp4:factor(occ2)15            .
# exp4:factor(occ2)16           -2.589619e-03
# exp4:factor(occ2)17           -9.827560e-04
# exp4:factor(occ2)18            .
# exp4:factor(occ2)19            .
# exp4:factor(occ2)20            .
# exp4:factor(occ2)21           -1.727022e-03
# exp4:factor(occ2)22            .
# exp4:factor(ind2)3            -1.858233e-03
# exp4:factor(ind2)4            -1.430419e-03
# exp4:factor(ind2)5             .
# exp4:factor(ind2)6             .
# exp4:factor(ind2)7             4.303729e-04
# exp4:factor(ind2)8             .
# exp4:factor(ind2)9             .
# exp4:factor(ind2)10            4.982051e-04
# exp4:factor(ind2)11            .
# exp4:factor(ind2)12            .
# exp4:factor(ind2)13            .
# exp4:factor(ind2)14            2.041040e-04
# exp4:factor(ind2)15           -3.093727e-04
# exp4:factor(ind2)16           -9.133463e-04
# exp4:factor(ind2)17            2.260880e-04
# exp4:factor(ind2)18           -8.777332e-06
# exp4:factor(ind2)19            .
# exp4:factor(ind2)20            .
# exp4:factor(ind2)21            .
# exp4:factor(ind2)22           -2.261675e-03
# hsg:scl                        .
# hsg:clg                        .
# hsg:ad                         .
# hsg:so                        -2.995014e-02
# hsg:we                         .
# hsg:ne                         .
# hsg:factor(occ2)2             -2.141287e-01
# hsg:factor(occ2)3              .
# hsg:factor(occ2)4             -6.666238e-02
# hsg:factor(occ2)5              1.677928e-02
# hsg:factor(occ2)6              .
# hsg:factor(occ2)7             -6.895183e-03
# hsg:factor(occ2)8             -1.468738e-01
# hsg:factor(occ2)9             -1.406930e-01
# hsg:factor(occ2)10            -8.468753e-02
# hsg:factor(occ2)11             .
# hsg:factor(occ2)12            -2.656983e-01
# hsg:factor(occ2)13             .
# hsg:factor(occ2)14             .
# hsg:factor(occ2)15             .
# hsg:factor(occ2)16            -2.212691e-01
# hsg:factor(occ2)17            -2.343777e-02
# hsg:factor(occ2)18            -2.151554e-01
# hsg:factor(occ2)19             1.844462e-01
# hsg:factor(occ2)20             1.674538e-01
# hsg:factor(occ2)21             2.461069e-02
# hsg:factor(occ2)22             4.118242e-02
# hsg:factor(ind2)3             -1.144321e-01
# hsg:factor(ind2)4              .
# hsg:factor(ind2)5              .
# hsg:factor(ind2)6             -3.199773e-02
# hsg:factor(ind2)7              .
# hsg:factor(ind2)8              1.325314e-01
# hsg:factor(ind2)9             -5.600567e-02
# hsg:factor(ind2)10             1.103447e-01
# hsg:factor(ind2)11             2.299204e-01
# hsg:factor(ind2)12             .
# hsg:factor(ind2)13            -1.094544e-02
# hsg:factor(ind2)14            -9.914700e-03
# hsg:factor(ind2)15             .
# hsg:factor(ind2)16             6.537460e-02
# hsg:factor(ind2)17             .
# hsg:factor(ind2)18             .
# hsg:factor(ind2)19            -2.198992e-01
# hsg:factor(ind2)20             .
# hsg:factor(ind2)21            -1.770494e-01
# hsg:factor(ind2)22             5.722280e-02
# scl:clg                        .
# scl:ad                         .
# scl:so                         6.038143e-02
# scl:we                         7.374199e-02
# scl:ne                         6.905372e-03
# scl:factor(occ2)2              1.677386e-01
# scl:factor(occ2)3              6.038989e-02
# scl:factor(occ2)4              .
# scl:factor(occ2)5             -1.139168e-01
# scl:factor(occ2)6              1.056890e-01
# scl:factor(occ2)7              1.977971e-05
# scl:factor(occ2)8             -2.857698e-01
# scl:factor(occ2)9              2.259094e-02
# scl:factor(occ2)10             .
# scl:factor(occ2)11            -4.940707e-02
# scl:factor(occ2)12             1.174440e-02
# scl:factor(occ2)13             1.424234e-02
# scl:factor(occ2)14             4.413030e-02
# scl:factor(occ2)15             .
# scl:factor(occ2)16            -1.276491e-01
# scl:factor(occ2)17             .
# scl:factor(occ2)18             7.626245e-01
# scl:factor(occ2)19             3.010787e-01
# scl:factor(occ2)20             1.986664e-01
# scl:factor(occ2)21             6.814433e-02
# scl:factor(occ2)22             2.369916e-02
# scl:factor(ind2)3             -1.048061e-01
# scl:factor(ind2)4              5.556708e-03
# scl:factor(ind2)5             -1.733826e-01
# scl:factor(ind2)6              1.223932e-02
# scl:factor(ind2)7              3.272269e-02
# scl:factor(ind2)8              7.628309e-02
# scl:factor(ind2)9             -1.772790e-01
# scl:factor(ind2)10            -4.370202e-03
# scl:factor(ind2)11             3.435389e-02
# scl:factor(ind2)12             5.842636e-02
# scl:factor(ind2)13             .
# scl:factor(ind2)14             4.919920e-02
# scl:factor(ind2)15            -1.692285e-01
# scl:factor(ind2)16             1.104256e-01
# scl:factor(ind2)17             .
# scl:factor(ind2)18            -5.493443e-03
# scl:factor(ind2)19             .
# scl:factor(ind2)20            -6.477235e-02
# scl:factor(ind2)21             8.320459e-03
# scl:factor(ind2)22             .
# clg:ad                         .
# clg:so                         4.976943e-02
# clg:we                        -1.786288e-02
# clg:ne                        -2.657957e-02
# clg:factor(occ2)2              .
# clg:factor(occ2)3              3.629310e-02
# clg:factor(occ2)4              1.038143e-01
# clg:factor(occ2)5             -6.037405e-02
# clg:factor(occ2)6             -9.209749e-02
# clg:factor(occ2)7              .
# clg:factor(occ2)8             -2.388128e-02
# clg:factor(occ2)9              .
# clg:factor(occ2)10             8.726286e-02
# clg:factor(occ2)11             .
# clg:factor(occ2)12             3.232660e-02
# clg:factor(occ2)13            -3.416326e-02
# clg:factor(occ2)14             2.841557e-02
# clg:factor(occ2)15             .
# clg:factor(occ2)16             .
# clg:factor(occ2)17            -2.600925e-03
# clg:factor(occ2)18             .
# clg:factor(occ2)19             2.378483e-01
# clg:factor(occ2)20            -1.690628e-01
# clg:factor(occ2)21            -1.413316e-01
# clg:factor(occ2)22            -2.245223e-01
# clg:factor(ind2)3              2.183238e-01
# clg:factor(ind2)4             -1.404862e-01
# clg:factor(ind2)5              4.052957e-02
# clg:factor(ind2)6              1.977240e-02
# clg:factor(ind2)7             -1.259511e-01
# clg:factor(ind2)8              .
# clg:factor(ind2)9             -3.340479e-01
# clg:factor(ind2)10            -5.282374e-03
# clg:factor(ind2)11             .
# clg:factor(ind2)12             .
# clg:factor(ind2)13             1.279578e-01
# clg:factor(ind2)14             .
# clg:factor(ind2)15             .
# clg:factor(ind2)16             .
# clg:factor(ind2)17            -1.131097e-01
# clg:factor(ind2)18            -5.408200e-02
# clg:factor(ind2)19            -6.009018e-02
# clg:factor(ind2)20            -7.168869e-02
# clg:factor(ind2)21             3.373048e-02
# clg:factor(ind2)22             .
# ad:so                          2.663665e-02
# ad:we                          .
# ad:ne                         -9.629981e-02
# ad:factor(occ2)2               9.554185e-03
# ad:factor(occ2)3               .
# ad:factor(occ2)4              -1.815447e-01
# ad:factor(occ2)5               .
# ad:factor(occ2)6              -1.806941e-01
# ad:factor(occ2)7               5.185127e-01
# ad:factor(occ2)8               .
# ad:factor(occ2)9              -1.529858e-01
# ad:factor(occ2)10              .
# ad:factor(occ2)11             -4.820909e-01
# ad:factor(occ2)12             -2.132588e-01
# ad:factor(occ2)13             -4.922221e-01
# ad:factor(occ2)14              .
# ad:factor(occ2)15             -3.907926e-02
# ad:factor(occ2)16              .
# ad:factor(occ2)17              1.678691e-05
# ad:factor(occ2)18              .
# ad:factor(occ2)19             -1.257143e-02
# ad:factor(occ2)20              .
# ad:factor(occ2)21              .
# ad:factor(occ2)22             -7.210985e-01
# ad:factor(ind2)3              -5.536724e-01
# ad:factor(ind2)4               2.399881e-01
# ad:factor(ind2)5               2.895930e-01
# ad:factor(ind2)6               .
# ad:factor(ind2)7               .
# ad:factor(ind2)8               4.106694e-01
# ad:factor(ind2)9               2.190270e-02
# ad:factor(ind2)10             -1.779161e-01
# ad:factor(ind2)11              1.990621e-02
# ad:factor(ind2)12              .
# ad:factor(ind2)13             -1.355276e-01
# ad:factor(ind2)14              8.967095e-02
# ad:factor(ind2)15              .
# ad:factor(ind2)16              5.567060e-02
# ad:factor(ind2)17             -2.557258e-02
# ad:factor(ind2)18              1.481312e-01
# ad:factor(ind2)19              .
# ad:factor(ind2)20              1.257556e-01
# ad:factor(ind2)21             -8.075981e-02
# ad:factor(ind2)22              .
# so:we                          .
# so:ne                          .
# so:factor(occ2)2              -7.081724e-02
# so:factor(occ2)3              -4.597650e-03
# so:factor(occ2)4               5.454049e-03
# so:factor(occ2)5              -2.000453e-01
# so:factor(occ2)6               .
# so:factor(occ2)7              -2.872838e-01
# so:factor(occ2)8               .
# so:factor(occ2)9               2.506776e-02
# so:factor(occ2)10             -6.797199e-02
# so:factor(occ2)11             -6.245827e-02
# so:factor(occ2)12             -3.587384e-01
# so:factor(occ2)13              .
# so:factor(occ2)14              1.149589e-01
# so:factor(occ2)15             -3.812436e-02
# so:factor(occ2)16             -1.026524e-01
# so:factor(occ2)17             -3.212806e-02
# so:factor(occ2)18              .
# so:factor(occ2)19             -1.563365e-01
# so:factor(occ2)20             -9.316109e-02
# so:factor(occ2)21              4.690033e-02
# so:factor(occ2)22             -1.276284e-01
# so:factor(ind2)3               1.651874e-01
# so:factor(ind2)4               .
# so:factor(ind2)5               9.258909e-03
# so:factor(ind2)6              -4.582127e-02
# so:factor(ind2)7               1.466241e-01
# so:factor(ind2)8               6.685564e-02
# so:factor(ind2)9              -3.924847e-02
# so:factor(ind2)10              5.930818e-02
# so:factor(ind2)11             -2.111802e-03
# so:factor(ind2)12             -4.409493e-02
# so:factor(ind2)13              .
# so:factor(ind2)14             -6.695160e-03
# so:factor(ind2)15              .
# so:factor(ind2)16             -2.195646e-01
# so:factor(ind2)17             -5.028592e-02
# so:factor(ind2)18             -1.289270e-03
# so:factor(ind2)19              .
# so:factor(ind2)20             -1.520210e-01
# so:factor(ind2)21              7.375111e-02
# so:factor(ind2)22              1.629606e-01
# we:ne                          .
# we:factor(occ2)2              -1.771820e-02
# we:factor(occ2)3               .
# we:factor(occ2)4               .
# we:factor(occ2)5               4.593884e-02
# we:factor(occ2)6              -4.778410e-02
# we:factor(occ2)7              -4.050215e-01
# we:factor(occ2)8              -3.280403e-02
# we:factor(occ2)9              -2.870905e-01
# we:factor(occ2)10             -6.542711e-02
# we:factor(occ2)11              1.715006e-02
# we:factor(occ2)12             -1.565768e-01
# we:factor(occ2)13             -6.011200e-02
# we:factor(occ2)14             -8.951979e-02
# we:factor(occ2)15              .
# we:factor(occ2)16              3.464856e-02
# we:factor(occ2)17             -3.291565e-02
# we:factor(occ2)18              .
# we:factor(occ2)19              .
# we:factor(occ2)20             -1.382804e-01
# we:factor(occ2)21              .
# we:factor(occ2)22              .
# we:factor(ind2)3               1.108522e-01
# we:factor(ind2)4               4.061512e-02
# we:factor(ind2)5               .
# we:factor(ind2)6               .
# we:factor(ind2)7               3.914394e-01
# we:factor(ind2)8               2.341020e-01
# we:factor(ind2)9               6.312854e-02
# we:factor(ind2)10             -8.429602e-02
# we:factor(ind2)11              1.246871e-01
# we:factor(ind2)12              .
# we:factor(ind2)13             -1.380287e-01
# we:factor(ind2)14             -2.905579e-02
# we:factor(ind2)15              1.663467e-01
# we:factor(ind2)16             -2.152368e-01
# we:factor(ind2)17              .
# we:factor(ind2)18             -2.932398e-02
# we:factor(ind2)19              5.183676e-02
# we:factor(ind2)20             -2.622981e-02
# we:factor(ind2)21              3.125086e-03
# we:factor(ind2)22              2.331469e-02
# ne:factor(occ2)2               .
# ne:factor(occ2)3               1.048800e-02
# ne:factor(occ2)4               .
# ne:factor(occ2)5               .
# ne:factor(occ2)6               2.252581e-02
# ne:factor(occ2)7               .
# ne:factor(occ2)8               7.595021e-02
# ne:factor(occ2)9               1.939682e-01
# ne:factor(occ2)10              2.164877e-01
# ne:factor(occ2)11              1.082774e-01
# ne:factor(occ2)12              1.748282e-01
# ne:factor(occ2)13              .
# ne:factor(occ2)14              2.944608e-02
# ne:factor(occ2)15              1.094299e-01
# ne:factor(occ2)16             -7.404486e-02
# ne:factor(occ2)17              7.288001e-02
# ne:factor(occ2)18              1.466846e-03
# ne:factor(occ2)19             -2.431240e-02
# ne:factor(occ2)20             -9.206411e-02
# ne:factor(occ2)21             -4.317536e-02
# ne:factor(occ2)22             -3.724163e-02
# ne:factor(ind2)3               .
# ne:factor(ind2)4              -1.155830e-03
# ne:factor(ind2)5              -7.477960e-02
# ne:factor(ind2)6              -6.831952e-02
# ne:factor(ind2)7               8.641370e-02
# ne:factor(ind2)8               .
# ne:factor(ind2)9               .
# ne:factor(ind2)10             -1.486540e-01
# ne:factor(ind2)11              8.575280e-02
# ne:factor(ind2)12              .
# ne:factor(ind2)13              .
# ne:factor(ind2)14              3.838537e-02
# ne:factor(ind2)15              7.382684e-01
# ne:factor(ind2)16              1.676942e-02
# ne:factor(ind2)17              .
# ne:factor(ind2)18             -1.145319e-01
# ne:factor(ind2)19              .
# ne:factor(ind2)20             -8.471420e-04
# ne:factor(ind2)21              .
# ne:factor(ind2)22              .
# factor(occ2)2:factor(ind2)3   -2.391274e-01
# factor(occ2)3:factor(ind2)3    .
# factor(occ2)4:factor(ind2)3    .
# factor(occ2)5:factor(ind2)3    2.669549e-02
# factor(occ2)6:factor(ind2)3    .
# factor(occ2)7:factor(ind2)3    .
# factor(occ2)8:factor(ind2)3    .
# factor(occ2)9:factor(ind2)3    .
# factor(occ2)10:factor(ind2)3   .
# factor(occ2)11:factor(ind2)3   .
# factor(occ2)12:factor(ind2)3  -2.099396e-01
# factor(occ2)13:factor(ind2)3   .
# factor(occ2)14:factor(ind2)3   .
# factor(occ2)15:factor(ind2)3   .
# factor(occ2)16:factor(ind2)3   .
# factor(occ2)17:factor(ind2)3   .
# factor(occ2)18:factor(ind2)3   .
# factor(occ2)19:factor(ind2)3  -1.808759e-01
# factor(occ2)20:factor(ind2)3   5.994200e-01
# factor(occ2)21:factor(ind2)3   2.583432e-01
# factor(occ2)22:factor(ind2)3   .
# factor(occ2)2:factor(ind2)4    1.550391e-01
# factor(occ2)3:factor(ind2)4    1.230124e-01
# factor(occ2)4:factor(ind2)4    .
# factor(occ2)5:factor(ind2)4    .
# factor(occ2)6:factor(ind2)4    .
# factor(occ2)7:factor(ind2)4    .
# factor(occ2)8:factor(ind2)4   -2.761857e-02
# factor(occ2)9:factor(ind2)4    .
# factor(occ2)10:factor(ind2)4   .
# factor(occ2)11:factor(ind2)4   .
# factor(occ2)12:factor(ind2)4   .
# factor(occ2)13:factor(ind2)4   .
# factor(occ2)14:factor(ind2)4   .
# factor(occ2)15:factor(ind2)4   .
# factor(occ2)16:factor(ind2)4   5.391792e-01
# factor(occ2)17:factor(ind2)4   .
# factor(occ2)18:factor(ind2)4   .
# factor(occ2)19:factor(ind2)4  -1.999186e-01
# factor(occ2)20:factor(ind2)4  -2.555823e-02
# factor(occ2)21:factor(ind2)4   1.261900e-01
# factor(occ2)22:factor(ind2)4   2.866359e-01
# factor(occ2)2:factor(ind2)5    .
# factor(occ2)3:factor(ind2)5    2.013604e-01
# factor(occ2)4:factor(ind2)5    1.222918e-01
# factor(occ2)5:factor(ind2)5   -1.123000e-01
# factor(occ2)6:factor(ind2)5    .
# factor(occ2)7:factor(ind2)5    .
# factor(occ2)8:factor(ind2)5    .
# factor(occ2)9:factor(ind2)5   -2.409792e-01
# factor(occ2)10:factor(ind2)5   6.289481e-01
# factor(occ2)11:factor(ind2)5   .
# factor(occ2)12:factor(ind2)5   .
# factor(occ2)13:factor(ind2)5  -1.242607e-01
# factor(occ2)14:factor(ind2)5  -2.148777e-02
# factor(occ2)15:factor(ind2)5   .
# factor(occ2)16:factor(ind2)5  -2.948158e-02
# factor(occ2)17:factor(ind2)5   .
# factor(occ2)18:factor(ind2)5  -1.740354e-02
# factor(occ2)19:factor(ind2)5   .
# factor(occ2)20:factor(ind2)5   3.603521e-01
# factor(occ2)21:factor(ind2)5  -6.174944e-02
# factor(occ2)22:factor(ind2)5  -1.714170e-01
# factor(occ2)2:factor(ind2)6    3.877147e-02
# factor(occ2)3:factor(ind2)6    3.005884e-01
# factor(occ2)4:factor(ind2)6    1.110857e-01
# factor(occ2)5:factor(ind2)6    4.918382e-01
# factor(occ2)6:factor(ind2)6    .
# factor(occ2)7:factor(ind2)6    .
# factor(occ2)8:factor(ind2)6    .
# factor(occ2)9:factor(ind2)6   -2.597537e-02
# factor(occ2)10:factor(ind2)6   .
# factor(occ2)11:factor(ind2)6   .
# factor(occ2)12:factor(ind2)6   .
# factor(occ2)13:factor(ind2)6   .
# factor(occ2)14:factor(ind2)6  -1.928250e-01
# factor(occ2)15:factor(ind2)6   .
# factor(occ2)16:factor(ind2)6   3.141264e-01
# factor(occ2)17:factor(ind2)6   1.428062e-02
# factor(occ2)18:factor(ind2)6   .
# factor(occ2)19:factor(ind2)6   .
# factor(occ2)20:factor(ind2)6  -1.392708e-01
# factor(occ2)21:factor(ind2)6   .
# factor(occ2)22:factor(ind2)6  -8.737868e-02
# factor(occ2)2:factor(ind2)7    .
# factor(occ2)3:factor(ind2)7    3.552535e-01
# factor(occ2)4:factor(ind2)7    .
# factor(occ2)5:factor(ind2)7    .
# factor(occ2)6:factor(ind2)7    .
# factor(occ2)7:factor(ind2)7    .
# factor(occ2)8:factor(ind2)7    .
# factor(occ2)9:factor(ind2)7    .
# factor(occ2)10:factor(ind2)7   .
# factor(occ2)11:factor(ind2)7   .
# factor(occ2)12:factor(ind2)7   .
# factor(occ2)13:factor(ind2)7   .
# factor(occ2)14:factor(ind2)7   .
# factor(occ2)15:factor(ind2)7   .
# factor(occ2)16:factor(ind2)7   3.996410e-01
# factor(occ2)17:factor(ind2)7  -1.478303e-01
# factor(occ2)18:factor(ind2)7   .
# factor(occ2)19:factor(ind2)7  -3.045718e-03
# factor(occ2)20:factor(ind2)7   2.350745e-01
# factor(occ2)21:factor(ind2)7  -3.260671e-01
# factor(occ2)22:factor(ind2)7  -1.930478e-01
# factor(occ2)2:factor(ind2)8   -3.426901e-01
# factor(occ2)3:factor(ind2)8   -4.330479e-01
# factor(occ2)4:factor(ind2)8    .
# factor(occ2)5:factor(ind2)8    .
# factor(occ2)6:factor(ind2)8    .
# factor(occ2)7:factor(ind2)8    .
# factor(occ2)8:factor(ind2)8    .
# factor(occ2)9:factor(ind2)8    .
# factor(occ2)10:factor(ind2)8   .
# factor(occ2)11:factor(ind2)8   .
# factor(occ2)12:factor(ind2)8   1.052789e-01
# factor(occ2)13:factor(ind2)8   .
# factor(occ2)14:factor(ind2)8   .
# factor(occ2)15:factor(ind2)8   .
# factor(occ2)16:factor(ind2)8   .
# factor(occ2)17:factor(ind2)8  -2.490395e-01
# factor(occ2)18:factor(ind2)8   .
# factor(occ2)19:factor(ind2)8   .
# factor(occ2)20:factor(ind2)8   8.289943e-01
# factor(occ2)21:factor(ind2)8   .
# factor(occ2)22:factor(ind2)8  -3.498070e-03
# factor(occ2)2:factor(ind2)9    3.545532e-01
# factor(occ2)3:factor(ind2)9   -3.790746e-02
# factor(occ2)4:factor(ind2)9    .
# factor(occ2)5:factor(ind2)9    .
# factor(occ2)6:factor(ind2)9    .
# factor(occ2)7:factor(ind2)9    2.211031e-01
# factor(occ2)8:factor(ind2)9    .
# factor(occ2)9:factor(ind2)9    1.072451e-01
# factor(occ2)10:factor(ind2)9   1.121939e-01
# factor(occ2)11:factor(ind2)9  -4.776645e-02
# factor(occ2)12:factor(ind2)9   .
# factor(occ2)13:factor(ind2)9  -8.179294e-02
# factor(occ2)14:factor(ind2)9  -4.084709e-01
# factor(occ2)15:factor(ind2)9   4.282905e-02
# factor(occ2)16:factor(ind2)9   .
# factor(occ2)17:factor(ind2)9   .
# factor(occ2)18:factor(ind2)9   .
# factor(occ2)19:factor(ind2)9  -2.394168e-03
# factor(occ2)20:factor(ind2)9  -1.731997e-02
# factor(occ2)21:factor(ind2)9   .
# factor(occ2)22:factor(ind2)9  -1.542241e-02
# factor(occ2)2:factor(ind2)10  -2.635687e-01
# factor(occ2)3:factor(ind2)10  -8.126041e-03
# factor(occ2)4:factor(ind2)10   .
# factor(occ2)5:factor(ind2)10   .
# factor(occ2)6:factor(ind2)10   .
# factor(occ2)7:factor(ind2)10   .
# factor(occ2)8:factor(ind2)10   .
# factor(occ2)9:factor(ind2)10   .
# factor(occ2)10:factor(ind2)10  .
# factor(occ2)11:factor(ind2)10  .
# factor(occ2)12:factor(ind2)10 -7.255279e-01
# factor(occ2)13:factor(ind2)10  .
# factor(occ2)14:factor(ind2)10  2.369847e-01
# factor(occ2)15:factor(ind2)10 -4.269617e-01
# factor(occ2)16:factor(ind2)10 -4.277143e-02
# factor(occ2)17:factor(ind2)10 -9.566234e-02
# factor(occ2)18:factor(ind2)10  .
# factor(occ2)19:factor(ind2)10  .
# factor(occ2)20:factor(ind2)10  .
# factor(occ2)21:factor(ind2)10  6.145297e-01
# factor(occ2)22:factor(ind2)10  7.165594e-02
# factor(occ2)2:factor(ind2)11   2.988053e-01
# factor(occ2)3:factor(ind2)11  -3.007315e-01
# factor(occ2)4:factor(ind2)11  -1.240581e-01
# factor(occ2)5:factor(ind2)11   .
# factor(occ2)6:factor(ind2)11   .
# factor(occ2)7:factor(ind2)11   .
# factor(occ2)8:factor(ind2)11  -1.001420e-01
# factor(occ2)9:factor(ind2)11  -1.623316e-01
# factor(occ2)10:factor(ind2)11  .
# factor(occ2)11:factor(ind2)11  .
# factor(occ2)12:factor(ind2)11  .
# factor(occ2)13:factor(ind2)11  .
# factor(occ2)14:factor(ind2)11 -5.619487e-01
# factor(occ2)15:factor(ind2)11  .
# factor(occ2)16:factor(ind2)11  1.211222e-01
# factor(occ2)17:factor(ind2)11 -9.227119e-02
# factor(occ2)18:factor(ind2)11  .
# factor(occ2)19:factor(ind2)11 -1.037289e+00
# factor(occ2)20:factor(ind2)11  .
# factor(occ2)21:factor(ind2)11  .
# factor(occ2)22:factor(ind2)11  3.494332e-02
# factor(occ2)2:factor(ind2)12   .
# factor(occ2)3:factor(ind2)12   1.296947e-01
# factor(occ2)4:factor(ind2)12   .
# factor(occ2)5:factor(ind2)12   .
# factor(occ2)6:factor(ind2)12   .
# factor(occ2)7:factor(ind2)12   7.445948e-01
# factor(occ2)8:factor(ind2)12  -5.773210e-01
# factor(occ2)9:factor(ind2)12   2.306173e-01
# factor(occ2)10:factor(ind2)12  7.580111e-02
# factor(occ2)11:factor(ind2)12  .
# factor(occ2)12:factor(ind2)12  3.016585e-01
# factor(occ2)13:factor(ind2)12  .
# factor(occ2)14:factor(ind2)12 -3.554176e-01
# factor(occ2)15:factor(ind2)12  .
# factor(occ2)16:factor(ind2)12  .
# factor(occ2)17:factor(ind2)12 -1.535702e-01
# factor(occ2)18:factor(ind2)12  .
# factor(occ2)19:factor(ind2)12  .
# factor(occ2)20:factor(ind2)12 -8.419497e-02
# factor(occ2)21:factor(ind2)12  .
# factor(occ2)22:factor(ind2)12  .
# factor(occ2)2:factor(ind2)13   9.297583e-02
# factor(occ2)3:factor(ind2)13   .
# factor(occ2)4:factor(ind2)13   .
# factor(occ2)5:factor(ind2)13   .
# factor(occ2)6:factor(ind2)13   .
# factor(occ2)7:factor(ind2)13   .
# factor(occ2)8:factor(ind2)13   .
# factor(occ2)9:factor(ind2)13   .
# factor(occ2)10:factor(ind2)13  .
# factor(occ2)11:factor(ind2)13  .
# factor(occ2)12:factor(ind2)13  .
# factor(occ2)13:factor(ind2)13  .
# factor(occ2)14:factor(ind2)13  2.202086e-01
# factor(occ2)15:factor(ind2)13  1.582786e-01
# factor(occ2)16:factor(ind2)13  7.924410e-03
# factor(occ2)17:factor(ind2)13  4.080641e-02
# factor(occ2)18:factor(ind2)13  .
# factor(occ2)19:factor(ind2)13  .
# factor(occ2)20:factor(ind2)13  1.855908e-01
# factor(occ2)21:factor(ind2)13  .
# factor(occ2)22:factor(ind2)13  .
# factor(occ2)2:factor(ind2)14   2.155420e-02
# factor(occ2)3:factor(ind2)14   9.424452e-02
# factor(occ2)4:factor(ind2)14   .
# factor(occ2)5:factor(ind2)14  -2.981151e-02
# factor(occ2)6:factor(ind2)14   .
# factor(occ2)7:factor(ind2)14   .
# factor(occ2)8:factor(ind2)14   1.106172e-01
# factor(occ2)9:factor(ind2)14   6.147288e-02
# factor(occ2)10:factor(ind2)14  1.814386e-01
# factor(occ2)11:factor(ind2)14 -2.232969e-01
# factor(occ2)12:factor(ind2)14  .
# factor(occ2)13:factor(ind2)14 -7.651182e-01
# factor(occ2)14:factor(ind2)14 -8.132391e-01
# factor(occ2)15:factor(ind2)14  .
# factor(occ2)16:factor(ind2)14  2.915394e-01
# factor(occ2)17:factor(ind2)14  8.267735e-04
# factor(occ2)18:factor(ind2)14  .
# factor(occ2)19:factor(ind2)14  .
# factor(occ2)20:factor(ind2)14 -7.407870e-01
# factor(occ2)21:factor(ind2)14  2.922130e-03
# factor(occ2)22:factor(ind2)14  1.309507e-01
# factor(occ2)2:factor(ind2)15  -2.324946e-01
# factor(occ2)3:factor(ind2)15   .
# factor(occ2)4:factor(ind2)15   .
# factor(occ2)5:factor(ind2)15   .
# factor(occ2)6:factor(ind2)15   .
# factor(occ2)7:factor(ind2)15   .
# factor(occ2)8:factor(ind2)15   .
# factor(occ2)9:factor(ind2)15   .
# factor(occ2)10:factor(ind2)15  .
# factor(occ2)11:factor(ind2)15  .
# factor(occ2)12:factor(ind2)15  .
# factor(occ2)13:factor(ind2)15  .
# factor(occ2)14:factor(ind2)15  .
# factor(occ2)15:factor(ind2)15  .
# factor(occ2)16:factor(ind2)15  .
# factor(occ2)17:factor(ind2)15  .
# factor(occ2)18:factor(ind2)15  .
# factor(occ2)19:factor(ind2)15  .
# factor(occ2)20:factor(ind2)15  .
# factor(occ2)21:factor(ind2)15  .
# factor(occ2)22:factor(ind2)15  .
# factor(occ2)2:factor(ind2)16   6.405604e-02
# factor(occ2)3:factor(ind2)16   1.987199e-01
# factor(occ2)4:factor(ind2)16   .
# factor(occ2)5:factor(ind2)16   4.834739e-01
# factor(occ2)6:factor(ind2)16   2.988417e-01
# factor(occ2)7:factor(ind2)16   1.724083e-01
# factor(occ2)8:factor(ind2)16   .
# factor(occ2)9:factor(ind2)16   .
# factor(occ2)10:factor(ind2)16  1.896307e-01
# factor(occ2)11:factor(ind2)16 -1.628659e-02
# factor(occ2)12:factor(ind2)16 -9.273370e-03
# factor(occ2)13:factor(ind2)16  .
# factor(occ2)14:factor(ind2)16 -2.451723e-01
# factor(occ2)15:factor(ind2)16  .
# factor(occ2)16:factor(ind2)16  9.372387e-02
# factor(occ2)17:factor(ind2)16  1.898077e-03
# factor(occ2)18:factor(ind2)16  .
# factor(occ2)19:factor(ind2)16  1.240524e-01
# factor(occ2)20:factor(ind2)16  .
# factor(occ2)21:factor(ind2)16  4.096888e-01
# factor(occ2)22:factor(ind2)16 -1.011089e-01
# factor(occ2)2:factor(ind2)17   1.714592e-02
# factor(occ2)3:factor(ind2)17   .
# factor(occ2)4:factor(ind2)17  -1.632780e-01
# factor(occ2)5:factor(ind2)17  -4.068214e-03
# factor(occ2)6:factor(ind2)17   3.215767e-01
# factor(occ2)7:factor(ind2)17   2.523999e-01
# factor(occ2)8:factor(ind2)17   .
# factor(occ2)9:factor(ind2)17   .
# factor(occ2)10:factor(ind2)17 -1.674466e-01
# factor(occ2)11:factor(ind2)17 -6.213691e-02
# factor(occ2)12:factor(ind2)17  .
# factor(occ2)13:factor(ind2)17 -4.524229e-01
# factor(occ2)14:factor(ind2)17  .
# factor(occ2)15:factor(ind2)17  1.768900e-01
# factor(occ2)16:factor(ind2)17  5.277539e-01
# factor(occ2)17:factor(ind2)17  .
# factor(occ2)18:factor(ind2)17  .
# factor(occ2)19:factor(ind2)17  1.208178e-01
# factor(occ2)20:factor(ind2)17  2.166241e-01
# factor(occ2)21:factor(ind2)17  .
# factor(occ2)22:factor(ind2)17 -2.316039e-02
# factor(occ2)2:factor(ind2)18   1.624316e-01
# factor(occ2)3:factor(ind2)18   4.037162e-01
# factor(occ2)4:factor(ind2)18   .
# factor(occ2)5:factor(ind2)18  -2.357489e-02
# factor(occ2)6:factor(ind2)18   .
# factor(occ2)7:factor(ind2)18   .
# factor(occ2)8:factor(ind2)18  -7.902187e-03
# factor(occ2)9:factor(ind2)18  -1.084569e-02
# factor(occ2)10:factor(ind2)18  8.609029e-02
# factor(occ2)11:factor(ind2)18  .
# factor(occ2)12:factor(ind2)18  .
# factor(occ2)13:factor(ind2)18  .
# factor(occ2)14:factor(ind2)18  3.554970e-02
# factor(occ2)15:factor(ind2)18 -6.073517e-02
# factor(occ2)16:factor(ind2)18  .
# factor(occ2)17:factor(ind2)18  1.082317e-01
# factor(occ2)18:factor(ind2)18  .
# factor(occ2)19:factor(ind2)18 -1.856320e-02
# factor(occ2)20:factor(ind2)18  .
# factor(occ2)21:factor(ind2)18 -1.088200e-01
# factor(occ2)22:factor(ind2)18  .
# factor(occ2)2:factor(ind2)19  -3.330545e-01
# factor(occ2)3:factor(ind2)19  -1.614476e-01
# factor(occ2)4:factor(ind2)19   .
# factor(occ2)5:factor(ind2)19   .
# factor(occ2)6:factor(ind2)19  -6.182180e-02
# factor(occ2)7:factor(ind2)19  -2.283223e-01
# factor(occ2)8:factor(ind2)19  -1.108912e-01
# factor(occ2)9:factor(ind2)19  -1.959629e-01
# factor(occ2)10:factor(ind2)19  .
# factor(occ2)11:factor(ind2)19  4.129297e-02
# factor(occ2)12:factor(ind2)19 -1.051074e+00
# factor(occ2)13:factor(ind2)19 -4.485078e-02
# factor(occ2)14:factor(ind2)19  .
# factor(occ2)15:factor(ind2)19 -3.477829e-01
# factor(occ2)16:factor(ind2)19 -2.841635e-01
# factor(occ2)17:factor(ind2)19 -1.953817e-01
# factor(occ2)18:factor(ind2)19  .
# factor(occ2)19:factor(ind2)19  .
# factor(occ2)20:factor(ind2)19 -5.723319e-01
# factor(occ2)21:factor(ind2)19  .
# factor(occ2)22:factor(ind2)19 -6.643280e-01
# factor(occ2)2:factor(ind2)20  -4.488828e-01
# factor(occ2)3:factor(ind2)20  -4.989835e-01
# factor(occ2)4:factor(ind2)20   .
# factor(occ2)5:factor(ind2)20   .
# factor(occ2)6:factor(ind2)20   .
# factor(occ2)7:factor(ind2)20   .
# factor(occ2)8:factor(ind2)20   1.128531e-01
# factor(occ2)9:factor(ind2)20   .
# factor(occ2)10:factor(ind2)20  .
# factor(occ2)11:factor(ind2)20  .
# factor(occ2)12:factor(ind2)20  2.476245e-02
# factor(occ2)13:factor(ind2)20  .
# factor(occ2)14:factor(ind2)20 -2.188068e-02
# factor(occ2)15:factor(ind2)20  5.505530e-01
# factor(occ2)16:factor(ind2)20 -1.537350e-01
# factor(occ2)17:factor(ind2)20  7.460981e-02
# factor(occ2)18:factor(ind2)20  .
# factor(occ2)19:factor(ind2)20 -1.008720e-01
# factor(occ2)20:factor(ind2)20 -3.957376e-01
# factor(occ2)21:factor(ind2)20 -9.159924e-02
# factor(occ2)22:factor(ind2)20  1.451668e-01
# factor(occ2)2:factor(ind2)21  -9.353997e-05
# factor(occ2)3:factor(ind2)21  -2.709024e-01
# factor(occ2)4:factor(ind2)21   6.115812e-01
# factor(occ2)5:factor(ind2)21   .
# factor(occ2)6:factor(ind2)21  -1.703898e-01
# factor(occ2)7:factor(ind2)21  -1.175735e-01
# factor(occ2)8:factor(ind2)21   .
# factor(occ2)9:factor(ind2)21   .
# factor(occ2)10:factor(ind2)21 -5.202890e-02
# factor(occ2)11:factor(ind2)21  .
# factor(occ2)12:factor(ind2)21  .
# factor(occ2)13:factor(ind2)21 -3.123303e-01
# factor(occ2)14:factor(ind2)21  .
# factor(occ2)15:factor(ind2)21  .
# factor(occ2)16:factor(ind2)21  1.197444e-01
# factor(occ2)17:factor(ind2)21 -8.692211e-02
# factor(occ2)18:factor(ind2)21  .
# factor(occ2)19:factor(ind2)21 -4.502997e-01
# factor(occ2)20:factor(ind2)21  4.158072e-02
# factor(occ2)21:factor(ind2)21  7.860096e-02
# factor(occ2)22:factor(ind2)21  9.469921e-02
# factor(occ2)2:factor(ind2)22  -6.360711e-02
# factor(occ2)3:factor(ind2)22   .
# factor(occ2)4:factor(ind2)22  -2.138314e-01
# factor(occ2)5:factor(ind2)22   3.263197e-02
# factor(occ2)6:factor(ind2)22  -9.240430e-02
# factor(occ2)7:factor(ind2)22   4.963343e-02
# factor(occ2)8:factor(ind2)22  -6.621264e-02
# factor(occ2)9:factor(ind2)22  -3.835072e-01
# factor(occ2)10:factor(ind2)22 -2.866697e-01
# factor(occ2)11:factor(ind2)22 -1.106432e-01
# factor(occ2)12:factor(ind2)22  .
# factor(occ2)13:factor(ind2)22  .
# factor(occ2)14:factor(ind2)22  .
# factor(occ2)15:factor(ind2)22 -1.271906e+00
# factor(occ2)16:factor(ind2)22 -4.367809e-01
# factor(occ2)17:factor(ind2)22 -1.088175e-01
# factor(occ2)18:factor(ind2)22  .
# factor(occ2)19:factor(ind2)22 -6.385915e-02
# factor(occ2)20:factor(ind2)22  .
# factor(occ2)21:factor(ind2)22  1.334021e-02
# factor(occ2)22:factor(ind2)22  1.872199e-01

# %% [markdown]
# 10. Now we use HDM for python (hdmpy) to estimate the model using the theoretically optimal penalty parameter.

# %%
install.packages("hdm")
library(hdm)

model_rlasso <- rlasso(X_flexible_train, y_train)
# Out:
# Warning message:
# "package 'hdm' is in use and will not be installed"

# %% [markdown]
# As you may notice, the optimal penalty parameter resulting from this procedure is not comparable in size to the cross validation result. This is due to the fact that this penalty is the theoretically optimal parameter for the Lasso estimator under data-driven penalty loadings. That is:
#
# \begin{equation*}
#
# \hat{\beta} = \arg \ \underset{\beta}{\min} \sum_{i=1}^n (y_i - x_{i}^{\prime}\beta)^2 + \frac{\lambda}{n} \lVert \hat{\Psi}\beta \rVert_1
#
# \end{equation*}
#
# Where $\hat{\Psi} = diag(\hat{\psi_1},\hat{\psi_2},\dots,\hat{\psi_p})$ are the data-driven penalty loadings chosen to be a function of the data depending on the setting. For more detail, you can check the [package documentation](https://arxiv.org/pdf/1608.00354)

# %%
rlambda = model_rlasso$lambda0
rlambda
# Out:
# [1] 616.2187

# %% [markdown]
# 11. The predictive capability of each model (OLS, Lasso and RLasso) is reported via $MSE$ and $R^2$ out of sample

# %%
y_predict_ols <- predict(model_ls, data.frame(X_flexible_test))

MSE_ols <- mean((y_test - y_predict_ols)^2)

R2_test_ols <- 1 - MSE_ols / var(y_test)
# Out:
# Warning message in predict.lm(model_ls, data.frame(X_flexible_test)):
# "prediction from rank-deficient fit; attr(*, "non-estim") has doubtful cases"

# %%
# Lasso CV

y_predict_lasso <- predict_model(model_lasso, X_flexible_test)
MSE_lasso <- mean((y_test - y_predict_lasso)^2)
R2_test_lasso <- 1 - MSE_lasso / var(y_test)

# %%
# Rigurous Lasso

y_predict_rlasso <- predict(model_rlasso, newdata = X_flexible_test)
MSE_rlasso <- mean((y_test - y_predict_rlasso)^2)
R2_test_rlasso <- 1 - MSE_rlasso / var(y_test)
